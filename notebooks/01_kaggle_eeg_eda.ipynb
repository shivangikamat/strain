# %% [markdown]
# # STRAIN — Kaggle emotions.csv EDA
#
# Run from repo root with `pip install -e .` and `data/emotions.csv` present.
#
# The CSV holds **tabular engineered features** (means, FFT bins, …) and `label` ∈ {NEGATIVE, NEUTRAL, POSITIVE}.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from strain.io.emotions_csv import load_emotions_csv
from strain.config import EMOTIONS_CSV

ds = load_emotions_csv(EMOTIONS_CSV)
print(ds.metadata)

# %%
import pandas as pd
df = pd.read_csv(EMOTIONS_CSV)
df.columns = [c.lstrip('#').strip() for c in df.columns]
df['label'].value_counts()

# %%
from strain.features.extract import extract_features
import numpy as np
for lab in sorted(set(ds.y)):
    i = int(np.where(ds.y == lab)[0][0])
    print(lab, extract_features(ds.X[i], ds.feature_names)['spectral_ratios'])
